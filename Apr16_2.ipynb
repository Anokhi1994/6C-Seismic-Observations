# %%
import obspy
from obspy import read
st_curlx = read('/home/ashah/Desktop/Apr16_2/r1.curlx')
st_curly = read('/home/ashah/Desktop/Apr16_2/r1.curly')
st_curlz = read('/home/ashah/Desktop/Apr16_2/r1.curlz')
st_x = read('/home/ashah/Desktop/Apr16_2/r1.x')
st_y = read('/home/ashah/Desktop/Apr16_2/r1.y')
st_z = read('/home/ashah/Desktop/Apr16_2/r1.z')
st_curlx.plot()
st_curly.plot()
st_curlz.plot()
st_x.plot()
st_y.plot()
st_z.plot()
