# %% [markdown]
# *Seismogram's from Shihao's input file*

# %%
import obspy
from obspy import read
st_curlx = read('/home/ashah/Desktop/Apr16_3/sta01.curlx')
st_curly = read('/home/ashah/Desktop/Apr16_3/sta01.curly')
st_curlz = read('/home/ashah/Desktop/Apr16_3/sta01.curlz')
st_x = read('/home/ashah/Desktop/Apr16_3/sta01.x')
st_y = read('/home/ashah/Desktop/Apr16_3/sta01.y')
st_z = read('/home/ashah/Desktop/Apr16_3/sta01.z')
st_curlx.plot()
st_curly.plot()
st_curlz.plot()
st_x.plot()
st_y.plot()
st_z.plot()

# %% [markdown]
# *Seismogram's from Anokhi's input file*

# %%
import obspy
from obspy import read
st_curlx = read('/home/ashah/Desktop/Apr16_2/sta01.curlx')
st_curly = read('/home/ashah/Desktop/Apr16_2/sta01.curly')
st_curlz = read('/home/ashah/Desktop/Apr16_2/sta01.curlz')
st_x = read('/home/ashah/Desktop/Apr16_2/sta01.x')
st_y = read('/home/ashah/Desktop/Apr16_2/sta01.y')
st_z = read('/home/ashah/Desktop/Apr16_2/sta01.z')
st_curlx.plot()
st_curly.plot()
st_curlz.plot()
st_x.plot()
st_y.plot()
st_z.plot()
